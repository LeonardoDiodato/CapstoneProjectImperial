# %% [markdown]
# # Function 4
# This function has 4 dimensions.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from scipy.stats import qmc

# %% [markdown]
# ### Data preparation
#
# Here we prepare the initial data provided

# %%
input = np.load('./initial_inputs.npy')
output = np.load('./initial_outputs.npy')
print(input)
print(output)
#print(input.shape)
#print(input.shape[1])
func_dimensions = input.shape[1]
print('this function has ', func_dimensions, ' dimensions')
# Out:
# [[0.89698105 0.72562797 0.17540431 0.70169437]
#  [0.8893564  0.49958786 0.53926886 0.50878344]
#  [0.25094624 0.03369313 0.14538002 0.49493242]
#  [0.34696206 0.0062504  0.76056361 0.61302356]
#  [0.12487118 0.12977019 0.38440048 0.2870761 ]
#  [0.80130271 0.50023109 0.70664456 0.19510284]
#  [0.24770826 0.06044543 0.04218635 0.44132425]
#  [0.74670224 0.7570915  0.36935306 0.20656628]
#  [0.40066503 0.07257425 0.88676825 0.24384229]
#  [0.6260706  0.58675126 0.43880578 0.77885769]
#  [0.95713529 0.59764438 0.76611385 0.77620991]
#  [0.73281243 0.14524998 0.47681272 0.13336573]
#  [0.65511548 0.07239183 0.68715175 0.08151656]
#  [0.21973443 0.83203134 0.48286416 0.08256923]
#  [0.48859419 0.2119651  0.93917791 0.37619173]
#  [0.16713049 0.87655456 0.21723954 0.95980098]
#  [0.21691119 0.16608583 0.24137226 0.77006248]
#  [0.38748784 0.80453226 0.75179548 0.72382744]
#  [0.98562189 0.66693268 0.15678328 0.8565348 ]
#  [0.03782483 0.66485335 0.16198218 0.25392378]
#  [0.68348638 0.9027701  0.33541983 0.99948256]
#  [0.17034731 0.75695908 0.27652049 0.5312315 ]
#  [0.85965692 0.91959232 0.20613873 0.09779683]
#  [0.28213837 0.50598691 0.53053084 0.09630162]
#  [0.32607578 0.4723669  0.453192   0.10588734]
#  [0.94838936 0.89451301 0.85163782 0.55219629]
#  [0.66495539 0.04656628 0.11677747 0.79371778]
#  [0.57776561 0.42877174 0.42582587 0.24900741]
#  [0.73861301 0.48210263 0.70936644 0.50397001]
#  [0.8548108  0.49396462 0.73530997 0.80809201]]
# [-22.10828779 -14.60139663 -11.69993246 -16.05376511 -10.06963343
#  -15.48708254 -12.68168498 -16.02639977 -17.04923465 -12.74176599
#  -27.31639636 -13.52764887 -16.6791152  -16.50715856 -17.81799934
#  -26.56182083 -12.75832422 -19.44155762 -28.90327367 -13.70274694
#  -29.4270914  -11.56574199 -26.85778644  -7.96677535  -6.70208925
#  -32.62566022 -19.98949793  -4.02554228 -13.12278233 -23.1394284 ]
# this function has  4  dimensions

# %% [markdown]
# Here we add the data provided with the weekly queries

# %%
additionalInputs = [[0.5, 0.5, 0.5, 0.5], [0.005543, 0.364356, 0.999366, 0.996013], [0.610283, 0.99932, 0.996058, 0.008603], [0.002628, 0.992778, 0.996738, 0.324661], [0.974265, 0.001353, 0.997995, 0.992941], [0.997834, 0.292695, 0.000728, 0.306473], [0.000918, 0.449159, 0.998156, 0.003407], [0.003596, 0.994216, 0.997743, 0.976803], [0.5601, 0.004018, 0.00039, 0.002926], [0.990495, 0.007398, 0.996884, 0.396862]]
#  [9.18000000e-04 4.49159000e-01 9.98156000e-01 3.40700000e-03]
#  [3.59600000e-03 9.94216000e-01 9.97743000e-01 9.76803000e-01]
#  [5.60100000e-01 4.01800000e-03 3.90000000e-04 2.92600000e-03]
#  [9.90495000e-01 7.39800000e-03 9.96884000e-01 3.96862000e-01]]
# [-22.10828779 -14.60139663 -11.69993246 -16.05376511 -10.06963343
#  -15.48708254 -12.68168498 -16.02639977 -17.04923465 -12.74176599
#  -27.31639636 -13.52764887 -16.6791152  -16.50715856 -17.81799934
#  -26.56182083 -12.75832422 -19.44155762 -28.90327367 -13.70274694
#  -29.4270914  -11.56574199 -26.85778644  -7.96677535  -6.70208925
#  -32.62566022 -19.98949793  -4.02554228 -13.12278233 -23.1394284
#   -3.98575097 -35.0510184  -36.45058527 -34.8370358  -46.19821449
#  -23.75034908 -27.71305146 -46.32018271 -21.32112375 -34.80391074]

# %% [markdown]
# # Bayesian Optimisation approach
# We approach the study of this function with the Bayesian Optimisation
# using and adaptation of the UCB acquisition function from required assignment 12.1

# %% [markdown]
# # Preparation of the exploration space
# Here we prepare the exploration space of the function<br>
# The values are increments of 0.01 bounded between 0 and 1 (included) => 101 values for each dimension of the space<br>
# dimension of the current function is stored in <b>func_dimensions</b>

# %%
#Initialise query lists and maximum observations
X, Y = input, output

#Initialise grid for plots
vector_values = np.linspace(0, 1, 101)# 101 values from 0 to 1
#print(vector_values)

# --- Latin Hypercube Sampling (LHS) ---
n_samples = 12100000
sampler_lhs = qmc.LatinHypercube(d=func_dimensions, seed=42)
x_grid = sampler_lhs.random(n=n_samples)
#print(f"LHS shape: {x_grid_lhs.shape}")

#x_grid = np.delete(x_grid, 0, axis=0)
#print(x_grid)
print(x_grid.shape)
# Out:
# (12100000, 4)

# %%
print(x_grid[:10])
# Out:
# [[0.86985556 0.11400368 0.33333001 0.93550986]
#  [0.71614793 0.12724389 0.00758514 0.84657324]
#  [0.78852181 0.79942608 0.17403658 0.934241  ]
#  [0.73645532 0.78907778 0.11008897 0.33621915]
#  [0.76935557 0.80082404 0.72514373 0.13989127]
#  [0.7918768  0.58363377 0.56063546 0.76386695]
#  [0.58766142 0.69050998 0.62139608 0.78102669]
#  [0.52910305 0.45143143 0.26587498 0.64555339]
#  [0.87749287 0.93012303 0.51989285 0.80570238]
#  [0.3407271  0.16489748 0.34225081 0.39673788]]

# %% [markdown]
# # Bayesian Optimisation with UCB applied

# %%
rbf_lengthscale = [0.1, 0.1, 0.1, 0.1]
real_noise_std = 1e-10
noise_assumption = 1e-10

#Define kernel of GP
kernel = RBF(length_scale=rbf_lengthscale, length_scale_bounds='fixed')

model = GaussianProcessRegressor(kernel = kernel)
#Fit the model
model.fit(np.array(X), np.array(Y).reshape(-1, 1))


#Calculate the mean and standard deviation and make them one-dimensional for plotting
post_mean, post_std = model.predict(x_grid, return_std=True)

#Acquisition function parameter
#beta = 1.96
#beta = 0.5
beta = 0.02

acquisition_function = post_mean + beta * post_std

grid = x_grid.squeeze()
obs = grid[np.argmax(acquisition_function)] #Else use the acquisition function

print('Next observation: ', obs)
#print (obs)
# Out:
# Next observation:  [0.00129271 0.44938165 0.72596276 0.51285894]
