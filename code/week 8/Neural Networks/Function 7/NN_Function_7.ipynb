# %% [markdown]
# # Neural Network approach to function 7

# %%
import numpy as np
import tensorflow as tf
import pickle
import os

# %% [markdown]
# ### Data preparation

# %%
input = np.load('./initial_inputs.npy')
output = np.load('./initial_outputs.npy')
print(input)
print(output)
#print(input.shape)
#print(input.shape[1])
func_dimensions = input.shape[1]
print('this function has ', func_dimensions, ' dimensions')
# Out:
# [[0.27262382 0.32449536 0.89710881 0.83295115 0.15406269 0.79586362]
#  [0.54300258 0.9246939  0.34156746 0.64648585 0.71844033 0.34313266]
#  [0.09083225 0.66152938 0.06593091 0.25857701 0.96345285 0.6402654 ]
#  [0.11886697 0.61505494 0.90581639 0.8553003  0.41363143 0.58523563]
#  [0.63021764 0.8380969  0.68001305 0.73189509 0.52673671 0.34842921]
#  [0.76491917 0.25588292 0.60908422 0.21807904 0.32294277 0.09579366]
#  [0.05789554 0.49167222 0.24742222 0.21811844 0.42042833 0.73096984]
#  [0.19525188 0.07922665 0.55458046 0.17056682 0.01494418 0.10703171]
#  [0.64230298 0.83687455 0.02179269 0.10148801 0.68307083 0.6924164 ]
#  [0.78994255 0.19554501 0.57562333 0.07365919 0.25904917 0.05109986]
#  [0.52849733 0.45742436 0.36009569 0.36204551 0.81689098 0.63747637]
#  [0.72261522 0.01181284 0.06364591 0.16517311 0.07924415 0.35995166]
#  [0.07566492 0.33450212 0.13273274 0.60831236 0.91838592 0.82233079]
#  [0.94245084 0.37743962 0.48612233 0.22879108 0.08263175 0.71195755]
#  [0.14864702 0.03394336 0.72880565 0.31606646 0.02176938 0.51691776]
#  [0.81711239 0.54816823 0.10334758 0.12436955 0.72823482 0.44967361]
#  [0.41762629 0.06409998 0.24566877 0.5590408  0.19153138 0.25464092]
#  [0.72628566 0.46489581 0.92457051 0.8072454  0.6354384  0.14341787]
#  [0.31981043 0.52009759 0.29067775 0.87670668 0.49503469 0.6190825 ]
#  [0.87987128 0.39796199 0.00363456 0.95699064 0.26451373 0.11486924]
#  [0.54124078 0.63140314 0.03190205 0.44998156 0.79865282 0.63370429]
#  [0.22634792 0.11502581 0.82474966 0.94538372 0.90531153 0.95101392]
#  [0.68685257 0.04101721 0.00757301 0.285009   0.69156848 0.6555429 ]
#  [0.17597754 0.6244165  0.29554198 0.46955276 0.09776977 0.72814108]
#  [0.88164674 0.20445019 0.41447436 0.42038468 0.26491501 0.73066019]
#  [0.06661051 0.52804507 0.8160952  0.96101714 0.08650933 0.77778822]
#  [0.93246638 0.48881189 0.25860774 0.95624344 0.19042781 0.51985176]
#  [0.84686697 0.14242917 0.06066859 0.75629213 0.5523983  0.08130609]
#  [0.80628208 0.32412237 0.72607601 0.14871213 0.7193764  0.36288398]
#  [0.47682313 0.34094195 0.01433523 0.88013956 0.9986547  0.07966402]]
# [0.6044327  0.56275307 0.00750324 0.0614243  0.2730468  0.08374657
#  1.3649683  0.09264495 0.0178696  0.03356494 0.0735163  0.2063097
#  0.00882563 0.26840032 0.61152553 0.01479818 0.27489251 0.06676325
#  0.04211835 0.00270147 0.01820907 0.00701603 0.10050661 0.47539552
#  0.67514163 0.51645722 0.00377748 0.00313433 0.02134252 0.09541116]
# this function has  6  dimensions

# %% [markdown]
# Additional data provided by weekly queries

# %%
additionalInputs = [[0.5, 0.5, 0.5, 0.5, 0.5, 0.5], [0.064108, 0.50467, 0.307547, 0.22933, 0.356495, 0.789273], [0.045203, 0.493887, 0.296157, 0.140072, 0.360602, 0.761422], [0.129753, 0.463468, 0.317766, 0.191937, 0.396281, 0.784369], [0.06782, 0.434119, 0.249574, 0.196558, 0.385974, 0.837422], [0.042636, 0.459636, 0.304379, 0.221496, 0.43641, 0.790166], [0.120728, 0.533888, 0.275139, 0.168882, 0.441824, 0.790651]]
additionalOutputs = [np.float64(0.5053149917022333), np.float64(1.5242238626243496), np.float64(1.348343558184188), np.float64(1.5755656391558395), np.float64(1.372546781524056), np.float64(1.3069906162600267), np.float64(1.0246878483199038)]

input = np.append(input, additionalInputs, axis=0)
output = np.append(output, additionalOutputs)

print(input)
print(output)
# Out:
# [[0.27262382 0.32449536 0.89710881 0.83295115 0.15406269 0.79586362]
#  [0.54300258 0.9246939  0.34156746 0.64648585 0.71844033 0.34313266]
#  [0.09083225 0.66152938 0.06593091 0.25857701 0.96345285 0.6402654 ]
#  [0.11886697 0.61505494 0.90581639 0.8553003  0.41363143 0.58523563]
#  [0.63021764 0.8380969  0.68001305 0.73189509 0.52673671 0.34842921]
#  [0.76491917 0.25588292 0.60908422 0.21807904 0.32294277 0.09579366]
#  [0.05789554 0.49167222 0.24742222 0.21811844 0.42042833 0.73096984]
#  [0.19525188 0.07922665 0.55458046 0.17056682 0.01494418 0.10703171]
#  [0.64230298 0.83687455 0.02179269 0.10148801 0.68307083 0.6924164 ]
#  [0.78994255 0.19554501 0.57562333 0.07365919 0.25904917 0.05109986]
#  [0.52849733 0.45742436 0.36009569 0.36204551 0.81689098 0.63747637]
#  [0.72261522 0.01181284 0.06364591 0.16517311 0.07924415 0.35995166]
#  [0.07566492 0.33450212 0.13273274 0.60831236 0.91838592 0.82233079]
#  [0.94245084 0.37743962 0.48612233 0.22879108 0.08263175 0.71195755]
#  [0.14864702 0.03394336 0.72880565 0.31606646 0.02176938 0.51691776]
#  [0.81711239 0.54816823 0.10334758 0.12436955 0.72823482 0.44967361]
#  [0.41762629 0.06409998 0.24566877 0.5590408  0.19153138 0.25464092]
#  [0.72628566 0.46489581 0.92457051 0.8072454  0.6354384  0.14341787]
#  [0.31981043 0.52009759 0.29067775 0.87670668 0.49503469 0.6190825 ]
#  [0.87987128 0.39796199 0.00363456 0.95699064 0.26451373 0.11486924]
#  [0.54124078 0.63140314 0.03190205 0.44998156 0.79865282 0.63370429]
#  [0.22634792 0.11502581 0.82474966 0.94538372 0.90531153 0.95101392]
#  [0.68685257 0.04101721 0.00757301 0.285009   0.69156848 0.6555429 ]
#  [0.17597754 0.6244165  0.29554198 0.46955276 0.09776977 0.72814108]
#  [0.88164674 0.20445019 0.41447436 0.42038468 0.26491501 0.73066019]
#  [0.06661051 0.52804507 0.8160952  0.96101714 0.08650933 0.77778822]
#  [0.93246638 0.48881189 0.25860774 0.95624344 0.19042781 0.51985176]
#  [0.84686697 0.14242917 0.06066859 0.75629213 0.5523983  0.08130609]
#  [0.80628208 0.32412237 0.72607601 0.14871213 0.7193764  0.36288398]
#  [0.47682313 0.34094195 0.01433523 0.88013956 0.9986547  0.07966402]
#  [0.5        0.5        0.5        0.5        0.5        0.5       ]
#  [0.064108   0.50467    0.307547   0.22933    0.356495   0.789273  ]
#  [0.045203   0.493887   0.296157   0.140072   0.360602   0.761422  ]
#  [0.129753   0.463468   0.317766   0.191937   0.396281   0.784369  ]
#  [0.06782    0.434119   0.249574   0.196558   0.385974   0.837422  ]
#  [0.042636   0.459636   0.304379   0.221496   0.43641    0.790166  ]
#  [0.120728   0.533888   0.275139   0.168882   0.441824   0.790651  ]]
# [0.6044327  0.56275307 0.00750324 0.0614243  0.2730468  0.08374657
#  1.3649683  0.09264495 0.0178696  0.03356494 0.0735163  0.2063097
#  0.00882563 0.26840032 0.61152553 0.01479818 0.27489251 0.06676325
#  0.04211835 0.00270147 0.01820907 0.00701603 0.10050661 0.47539552
#  0.67514163 0.51645722 0.00377748 0.00313433 0.02134252 0.09541116
#  0.50531499 1.52422386 1.34834356 1.57556564 1.37254678 1.30699062
#  1.02468785]

# %% [markdown]
# # Neural network setup
# Here we prepare a neural network to approach function 5
#
# This requires 4 inputs and 1 output
#
# We decide to apply 2 hidden layers of 8 nodes each
#
# The activation function will be a tanh

# %%
# 1. Define the input data and target output for demonstration
x_train = np.array(input, dtype=np.float32)
y_train = np.array(output, dtype=np.float32).reshape(-1, 1)

# Normalize the output (CRITICAL for training)
y_mean = np.mean(y_train)
y_std = np.std(y_train)
y_train_normalized = (y_train - y_mean) / y_std

print(f"Output normalized: mean={y_mean:.2f}, std={y_std:.2f}")
# Out:
# Output normalized: mean=0.41, std=0.50

# %%
print(x_train)
print(y_train)
print(len(x_train))
print(len(y_train))
# Out:
# [[0.2726238  0.32449538 0.8971088  0.8329511  0.15406269 0.7958636 ]
#  [0.5430026  0.9246939  0.34156746 0.64648587 0.71844035 0.34313267]
#  [0.09083225 0.66152936 0.06593091 0.25857702 0.9634529  0.6402654 ]
#  [0.11886697 0.61505497 0.9058164  0.8553003  0.41363144 0.58523566]
#  [0.6302176  0.8380969  0.68001306 0.7318951  0.52673674 0.3484292 ]
#  [0.76491916 0.25588292 0.60908425 0.21807905 0.32294276 0.09579366]
#  [0.05789554 0.49167222 0.24742222 0.21811843 0.42042834 0.73096985]
#  [0.19525188 0.07922665 0.55458045 0.17056683 0.01494418 0.10703171]
#  [0.642303   0.83687454 0.02179269 0.10148801 0.68307084 0.6924164 ]
#  [0.78994256 0.195545   0.57562333 0.07365919 0.25904918 0.05109986]
#  [0.52849734 0.45742434 0.36009568 0.3620455  0.81689095 0.6374764 ]
#  [0.72261524 0.01181284 0.06364591 0.16517311 0.07924414 0.35995165]
#  [0.07566492 0.33450213 0.13273273 0.60831237 0.9183859  0.8223308 ]
#  [0.9424508  0.37743962 0.48612234 0.22879109 0.08263174 0.7119576 ]
#  [0.14864703 0.03394336 0.72880566 0.31606644 0.02176938 0.51691777]
#  [0.8171124  0.54816824 0.10334758 0.12436955 0.7282348  0.44967362]
#  [0.4176263  0.06409998 0.24566877 0.5590408  0.19153139 0.25464094]
#  [0.72628564 0.4648958  0.9245705  0.8072454  0.6354384  0.14341788]
#  [0.31981042 0.5200976  0.29067776 0.87670666 0.4950347  0.6190825 ]
#  [0.87987125 0.397962   0.00363456 0.95699066 0.26451373 0.11486924]
#  [0.54124075 0.63140315 0.03190205 0.44998157 0.7986528  0.6337043 ]
#  [0.22634792 0.11502581 0.82474965 0.9453837  0.9053115  0.9510139 ]
#  [0.6868526  0.04101721 0.00757301 0.285009   0.6915685  0.6555429 ]
#  [0.17597754 0.6244165  0.29554197 0.46955276 0.09776977 0.72814107]
#  [0.88164675 0.20445019 0.41447437 0.42038468 0.26491502 0.7306602 ]
#  [0.06661051 0.52804506 0.8160952  0.96101713 0.08650933 0.7777882 ]
#  [0.9324664  0.48881188 0.25860775 0.95624346 0.19042781 0.51985174]
#  [0.84686697 0.14242917 0.06066859 0.7562921  0.5523983  0.08130608]
#  [0.8062821  0.32412237 0.726076   0.14871213 0.7193764  0.36288399]
#  [0.47682312 0.34094194 0.01433523 0.8801396  0.9986547  0.07966402]
#  [0.5        0.5        0.5        0.5        0.5        0.5       ]
#  [0.064108   0.50467    0.307547   0.22933    0.356495   0.789273  ]
#  [0.045203   0.493887   0.296157   0.140072   0.360602   0.761422  ]
#  [0.129753   0.463468   0.317766   0.191937   0.396281   0.784369  ]
#  [0.06782    0.434119   0.249574   0.196558   0.385974   0.837422  ]
#  [0.042636   0.459636   0.304379   0.221496   0.43641    0.790166  ]
#  [0.120728   0.533888   0.275139   0.168882   0.441824   0.790651  ]]
# [[0.6044327 ]
#  [0.5627531 ]
#  [0.00750324]
#  [0.0614243 ]
#  [0.2730468 ]
#  [0.08374657]
#  [1.3649683 ]
#  [0.09264495]
#  [0.0178696 ]
#  [0.03356494]
#  [0.0735163 ]
#  [0.20630969]
#  [0.00882563]
#  [0.2684003 ]
#  [0.61152554]
#  [0.01479818]
#  [0.2748925 ]
#  [0.06676324]
#  [0.04211836]
#  [0.00270147]
#  [0.01820907]
#  [0.00701603]
#  [0.10050661]
#  [0.47539553]
#  [0.67514163]
#  [0.5164572 ]
#  [0.00377748]
#  [0.00313433]
#  [0.02134252]
#  [0.09541116]
#  [0.505315  ]
#  [1.5242238 ]
#  [1.3483436 ]
#  [1.5755657 ]
#  [1.3725468 ]
#  [1.3069906 ]
#  [1.0246879 ]]
# 37
# 37

# %%
# Initialize weights with better initialization (Xavier/Glorot)
W1 = tf.Variable(tf.random.normal([7, 12], stddev=np.sqrt(2.0/5)), dtype=tf.float32)  # 6 inputs + 1 bias
W2 = tf.Variable(tf.random.normal([13, 12], stddev=np.sqrt(2.0/9)), dtype=tf.float32)  # 12 hidden + 1 bias
W3 = tf.Variable(tf.random.normal([12, 1], stddev=np.sqrt(2.0/8)), dtype=tf.float32)  # 12 hidden to 1 output
print(W1)
print(W2)
print(W3)
# Out:
# <tf.Variable 'Variable:0' shape=(7, 12) dtype=float32, numpy=
# array([[ 0.19514214, -0.9158555 ,  0.3927028 ,  0.41211736,  0.09855016,
#          0.75134   , -0.55006856, -0.87633777, -0.18932079, -0.47857335,
#         -0.7826843 , -0.19426337],
#        [-0.4364993 , -1.5604193 , -1.1358479 , -0.59828526, -0.6293758 ,
#          1.8799788 ,  0.4182103 , -0.49697667, -0.38835078, -0.6818243 ,
#         -0.3321777 , -0.1114894 ],
#        [ 0.17550883, -0.5766975 , -0.92166865, -0.36053947,  0.13205132,
#          0.30277997, -0.26559386, -0.635268  , -0.4853976 , -0.15724894,
#         -0.29438087,  0.9574915 ],
#        [-0.00875299,  0.0670704 , -0.10600499,  0.07368073,  0.7904248 ,
#          0.52831453, -0.6488384 , -0.49395132, -0.4955501 ,  0.40539843,
#         -0.4631759 ,  0.18747711],
#        [-0.15793487, -0.56764394, -0.3622086 , -1.3706213 ,  0.04485205,
#         -0.25432944,  0.770005  , -0.53627   , -0.5249241 , -0.36927125,
#          0.7928613 ,  0.3746082 ],
#        [ 0.20596011, -1.5952859 , -1.0539539 ,  0.10681263, -0.28848848,
#          0.03428214, -0.3931674 , -0.04468308, -0.17162123, -0.9391096 ,
#          0.5897543 ,  0.500543  ],
#        [-0.6798212 , -1.7123108 , -0.54518056, -0.7128132 , -0.02689287,
#         -0.77104646,  0.10207137, -0.18483186,  0.8396104 ,  0.11769205,
#         -0.09066168,  0.9196124 ]], dtype=float32)>
# <tf.Variable 'Variable:0' shape=(13, 12) dtype=float32, numpy=
# array([[-0.00457667, -0.02683456, -0.34957114, -0.13864537, -0.34358308,
#          0.07312442,  0.48802376, -0.05128739, -0.13472472,  0.07610717,
#          0.3277011 ,  0.12824231],
#        [ 0.57731175, -0.45069015, -0.38578895, -0.3289006 ,  0.67432165,
#          0.37602475, -0.06874456, -0.39231086,  0.22995314, -0.3423328 ,
#         -0.11992082,  0.18412383],
#        [ 0.03142491,  0.22351545,  0.5695678 , -0.01131145, -0.83083576,
#         -0.75692374, -0.44609725, -0.01729713,  0.16038845,  0.02787842,
#         -0.7793408 , -0.4702457 ],
#        [ 1.2239012 ,  0.22840935,  0.32492658, -0.84804267, -0.42612404,
#         -0.19144095,  0.19914389, -0.7802423 ,  0.15943016,  0.5208609 ,
#         -0.2985892 ,  0.04300483],
#        [-0.62402755, -0.11432442, -0.7682612 , -0.30282146,  0.34873894,
#          0.3676345 , -0.55443525,  0.32551518,  0.6728254 ,  0.12815124,
#          0.61387235, -0.05390916],
#        [ 0.2362421 ,  0.3356783 , -0.4462566 , -0.5037768 ,  0.5688797 ,
#          0.7697896 , -0.5614228 ,  0.75572246, -0.01563846,  0.09054576,
#          0.187386  , -0.19262274],
#        [ 0.6394842 , -0.20921259, -0.20510978,  0.83519125,  0.26473907,
#         -0.4134661 ,  0.3577932 ,  0.41723865, -0.7759563 , -0.88009346,
#          0.7878098 ,  0.32623515],
#        [ 0.07101208, -0.2830687 ,  0.05621531, -0.34706175, -0.38644454,
#         -0.32429585, -0.76625425,  1.1663251 , -0.44226483, -0.3147963 ,
#         -0.14695038, -0.19809534],
#        [ 0.20274718,  0.5159219 ,  0.15374097,  0.62889594,  0.06875003,
#          0.28250405,  0.17970166, -0.7980863 ,  0.39733052,  0.49542266,
#          0.459924  , -0.54810333],
#        [ 0.04982976,  0.306842  ,  0.05798076,  0.42180398, -0.22575802,
#          0.39950207,  0.35267046, -0.40039355,  0.02913458,  0.65373135,
#          0.3006428 ,  0.8832121 ],
#        [ 0.11331464, -0.24949726, -0.3301713 , -0.14908855,  0.30011937,
#          0.06804914, -0.11656225,  0.12074274,  0.39278713, -0.4570994 ,
#          0.00868216,  0.6241965 ],
#        [ 0.01684846, -0.38545755, -0.45786682, -0.20634338,  0.41950926,
#          0.00699014,  0.06296076, -0.2730331 , -0.6686384 ,  0.18999584,
#          0.26137924, -0.68826276],
#        [-0.4508211 , -0.7613631 ,  0.3106791 ,  0.3880591 ,  0.33655432,
#         -0.30094114,  0.38600388,  0.12691009,  0.5295468 ,  0.88733596,
#          0.9160129 ,  0.45175633]], dtype=float32)>
# <tf.Variable 'Variable:0' shape=(12, 1) dtype=float32, numpy=
# array([[ 0.49446267],
#        [-0.27875566],
#        [ 0.9097742 ],
#        [-0.5448013 ],
#        [-0.7764182 ],
#        [ 0.1956203 ],
#        [-0.09850421],
#        [ 1.23575   ],
#        [ 0.34698388],
#        [-0.6069211 ],
#        [ 0.34905165],
#        [ 0.0282833 ]], dtype=float32)>

# %%
@tf.function
def forward_pass(x_batch):
    # x_batch shape: (batch_size, 4)
    batch_size = tf.shape(x_batch)[0]
    bias = tf.ones((batch_size, 1), dtype=tf.float32)

    # First hidden layer
    x_with_bias = tf.concat([x_batch, bias], axis=1)  # (batch_size, 5)
    hidden1 = tf.nn.tanh(tf.matmul(x_with_bias, W1))  # (batch_size, 8)

    # Second hidden layer
    hidden1_with_bias = tf.concat([hidden1, bias], axis=1)  # (batch_size, 9)
    hidden2 = tf.nn.tanh(tf.matmul(hidden1_with_bias, W2))  # (batch_size, 8)

    # Output layer (LINEAR, no sigmoid!)
    output = tf.matmul(hidden2, W3)  # (batch_size, 1)

    return output


#print(forward_pass(x_train[0].reshape(4,-1)))

# %%
# Loss and optimizer
loss_fn = tf.keras.losses.MeanSquaredError()
optimizer = tf.optimizers.SGD(learning_rate=0.01)  # Lower learning rate
print(loss_fn)
print(optimizer)
# Out:
# <LossFunctionWrapper(<function mean_squared_error at 0x7a4ce0938f40>, kwargs={})>
# <keras.src.optimizers.sgd.SGD object at 0x7a4cc09ea120>

# %%
@tf.function
def train_step(x, y):
    with tf.GradientTape() as tape:
        y_pred = forward_pass(x)
        loss = loss_fn(y, y_pred)
    gradients = tape.gradient(loss, [W1, W2, W3])
    optimizer.apply_gradients(zip(gradients, [W1, W2, W3]))
    return loss


###END SOLUTION
#for i, v in enumerate(x_train):
#  print(train_step(x_train[i].reshape(4,-1), y_train[i]))
#for epoch in range(10):
#  print(train_step(x_train[0].reshape(4,-1), y_train[0].reshape(1,1)))
# Training loop
print("\nTraining...")
epochs = 50000
for epoch in range(epochs):
    loss = train_step(x_train, y_train_normalized)

    if epoch % 500 == 0:
        print(f"Epoch {epoch}, Loss: {loss.numpy():.6f}")
# Out:
# Training...
# Epoch 0, Loss: 2.892851
# Epoch 500, Loss: 0.233991
# Epoch 1000, Loss: 0.160952
# Epoch 1500, Loss: 0.123211
# Epoch 2000, Loss: 0.097827
# Epoch 2500, Loss: 0.081768
# Epoch 3000, Loss: 0.072243
# Epoch 3500, Loss: 0.066095
# Epoch 4000, Loss: 0.061777
# Epoch 4500, Loss: 0.058589
# Epoch 5000, Loss: 0.056155
# Epoch 5500, Loss: 0.054239
# Epoch 6000, Loss: 0.052681
# Epoch 6500, Loss: 0.051368
# Epoch 7000, Loss: 0.050224
# Epoch 7500, Loss: 0.049201
# Epoch 8000, Loss: 0.048265
# Epoch 8500, Loss: 0.047399
# Epoch 9000, Loss: 0.046589
# Epoch 9500, Loss: 0.045827
# Epoch 10000, Loss: 0.045105
# Epoch 10500, Loss: 0.044419
# Epoch 11000, Loss: 0.043764
# Epoch 11500, Loss: 0.043138
# Epoch 12000, Loss: 0.042536
# Epoch 12500, Loss: 0.041955
# Epoch 13000, Loss: 0.041393
# Epoch 13500, Loss: 0.040847
# Epoch 14000, Loss: 0.040314
# Epoch 14500, Loss: 0.039792
# Epoch 15000, Loss: 0.039277
# Epoch 15500, Loss: 0.038767
# Epoch 16000, Loss: 0.038260
# Epoch 16500, Loss: 0.037753
# Epoch 17000, Loss: 0.037246
# Epoch 17500, Loss: 0.036737
# Epoch 18000, Loss: 0.036225
# Epoch 18500, Loss: 0.035709
# Epoch 19000, Loss: 0.035190
# Epoch 19500, Loss: 0.034667
# Epoch 20000, Loss: 0.034142
# Epoch 20500, Loss: 0.033614
# Epoch 21000, Loss: 0.033084
# Epoch 21500, Loss: 0.032552
# Epoch 22000, Loss: 0.032019
# Epoch 22500, Loss: 0.031484
# Epoch 23000, Loss: 0.030949
# Epoch 23500, Loss: 0.030412
# Epoch 24000, Loss: 0.029874
# Epoch 24500, Loss: 0.029336
# Epoch 25000, Loss: 0.028795
# Epoch 25500, Loss: 0.028253
# Epoch 26000, Loss: 0.027709
# Epoch 26500, Loss: 0.027161
# Epoch 27000, Loss: 0.026610
# Epoch 27500, Loss: 0.026055
# Epoch 28000, Loss: 0.025494
# Epoch 28500, Loss: 0.024928
# Epoch 29000, Loss: 0.024354
# Epoch 29500, Loss: 0.023772
# Epoch 30000, Loss: 0.023182
# Epoch 30500, Loss: 0.022582
# Epoch 31000, Loss: 0.021972
# Epoch 31500, Loss: 0.021351
# Epoch 32000, Loss: 0.020720
# Epoch 32500, Loss: 0.020079
# Epoch 33000, Loss: 0.019428
# Epoch 33500, Loss: 0.018770
# Epoch 34000, Loss: 0.018105
# Epoch 34500, Loss: 0.017436
# Epoch 35000, Loss: 0.016766
# Epoch 35500, Loss: 0.016097
# Epoch 36000, Loss: 0.015435
# Epoch 36500, Loss: 0.014782
# Epoch 37000, Loss: 0.014143
# Epoch 37500, Loss: 0.013522
# Epoch 38000, Loss: 0.012922
# Epoch 38500, Loss: 0.012347
# Epoch 39000, Loss: 0.011799
# Epoch 39500, Loss: 0.011279
# Epoch 40000, Loss: 0.010789
# Epoch 40500, Loss: 0.010328
# Epoch 41000, Loss: 0.009896
# Epoch 41500, Loss: 0.009492
# Epoch 42000, Loss: 0.009114
# Epoch 42500, Loss: 0.008760
# Epoch 43000, Loss: 0.008429
# Epoch 43500, Loss: 0.008119
# Epoch 44000, Loss: 0.007828
# Epoch 44500, Loss: 0.007555
# Epoch 45000, Loss: 0.007299
# Epoch 45500, Loss: 0.007058
# Epoch 46000, Loss: 0.006831
# Epoch 46500, Loss: 0.006617
# Epoch 47000, Loss: 0.006415
# Epoch 47500, Loss: 0.006225
# Epoch 48000, Loss: 0.006044
# Epoch 48500, Loss: 0.005873
# Epoch 49000, Loss: 0.005711
# Epoch 49500, Loss: 0.005558

# %%
# ============================================================================
# SAVE WEIGHTS FUNCTION
# ============================================================================
def save_weights(filepath='model_weights.pkl'):
    """
    Save the trained weights and normalization parameters to a file.

    Args:
        filepath: Path where to save the weights (default: 'model_weights.pkl')
    """
    weights_dict = {
        'W1': W1.numpy(),
        'W2': W2.numpy(),
        'W3': W3.numpy(),
        'y_mean': y_mean,
        'y_std': y_std
    }

    with open(filepath, 'wb') as f:
        pickle.dump(weights_dict, f)

    print(f"\n✓ Weights saved to '{filepath}'")

# %%
# ============================================================================
# LOAD WEIGHTS FUNCTION
# ============================================================================
def load_weights(filepath='model_weights.pkl'):
    """
    Load previously saved weights and normalization parameters.

    Args:
        filepath: Path to the saved weights file

    Returns:
        tuple: (y_mean, y_std) normalization parameters
    """
    global W1, W2, W3, y_mean, y_std

    if not os.path.exists(filepath):
        raise FileNotFoundError(f"Weights file '{filepath}' not found!")

    with open(filepath, 'rb') as f:
        weights_dict = pickle.load(f)

    # Load weights into TensorFlow variables
    W1.assign(weights_dict['W1'])
    W2.assign(weights_dict['W2'])
    W3.assign(weights_dict['W3'])

    # Load normalization parameters
    y_mean = weights_dict['y_mean']
    y_std = weights_dict['y_std']

    print(f"\n✓ Weights loaded from '{filepath}'")
    return y_mean, y_std

# %%
# ============================================================================
# PREDICTION FUNCTION (for inference with loaded model)
# ============================================================================
def predict(x_input, y_mean, y_std):
    """
    Make predictions on new data using the loaded model.

    Args:
        x_input: Input data (numpy array of shape [n_samples, 4])
        y_mean: Mean used for normalization
        y_std: Standard deviation used for normalization

    Returns:
        Predictions in original scale
    """
    x_input = np.array(x_input, dtype=np.float32)
    if len(x_input.shape) == 1:
        x_input = x_input.reshape(1, -1)

    predictions_normalized = forward_pass(x_input).numpy()
    predictions = predictions_normalized * y_std + y_mean

    return predictions

# %%
# ============================================================================
# TRAINING MODE
# ============================================================================
TRAIN_MODE = True  # Set to False to skip training and only load weights

if TRAIN_MODE:
    print("\nTraining...")
    epochs = 500
    for epoch in range(epochs):
        loss = train_step(x_train, y_train_normalized)

        if epoch % 500 == 0:
            print(f"Epoch {epoch}, Loss: {loss.numpy():.6f}")

    # Make predictions
    print("\n" + "="*70)
    print("Training Results:")
    print("="*70)
    predictions_normalized = forward_pass(x_train).numpy()
    predictions = predictions_normalized * y_std + y_mean

    print(f"{'Actual':<15} {'Predicted':<15} {'Error':<15}")
    print("-"*70)
    for i in range(len(y_train)):
        actual = y_train[i, 0]
        predicted = predictions[i, 0]
        error = abs(actual - predicted)
        print(f"{actual:<15.2f} {predicted:<15.2f} {error:<15.2f}")

    mse = np.mean((predictions - y_train) ** 2)
    mae = np.mean(np.abs(predictions - y_train))
    print("="*70)
    print(f"Mean Squared Error: {mse:.2f}")
    print(f"Mean Absolute Error: {mae:.2f}")

    # Save the trained weights
    save_weights('model_weights.pkl')

# ============================================================================
# INFERENCE MODE (Load weights and make predictions)
# ============================================================================
else:
    print("\n" + "="*70)
    print("INFERENCE MODE - Loading saved weights")
    print("="*70)

    # Load previously saved weights
    y_mean, y_std = load_weights('model_weights.pkl')

    # Make predictions on the training data (or new data)
    print("\nMaking predictions with loaded model...")
    predictions = predict(x_train, y_mean, y_std)

    print(f"\n{'Actual':<15} {'Predicted':<15} {'Error':<15}")
    print("-"*70)
    for i in range(len(y_train)):
        actual = y_train[i, 0]
        predicted = predictions[i, 0]
        error = abs(actual - predicted)
        print(f"{actual:<15.2f} {predicted:<15.2f} {error:<15.2f}")

    # Example: Make a prediction on a new sample
    print("\n" + "="*70)
    print("Example prediction on new data:")
    print("="*70)
    new_sample = np.array([[0.5, 0.5, 0.5, 0.5]])
    new_prediction = predict(new_sample, y_mean, y_std)
    print(f"Input: {new_sample[0]}")
    print(f"Predicted output: {new_prediction[0, 0]:.2f}")
# Out:
# Training...
# Epoch 0, Loss: 0.005412
#
# ======================================================================
# Training Results:
# ======================================================================
# Actual          Predicted       Error
# ----------------------------------------------------------------------
# 0.60            0.60            0.00
# 0.56            0.58            0.02
# 0.01            -0.02           0.03
# 0.06            0.07            0.01
# 0.27            0.29            0.01
# 0.08            0.08            0.01
# 1.36            1.28            0.09
# 0.09            0.09            0.00
# 0.02            0.01            0.01
# 0.03            0.04            0.00
# 0.07            0.11            0.04
# 0.21            0.21            0.00
# 0.01            0.01            0.00
# 0.27            0.27            0.00
# 0.61            0.61            0.00
# 0.01            0.02            0.00
# 0.27            0.28            0.00
# 0.07            0.06            0.01
# 0.04            0.04            0.00
# 0.00            -0.01           0.02
# 0.02            0.02            0.01
# 0.01            0.01            0.00
# 0.10            0.10            0.00
# 0.48            0.49            0.01
# 0.68            0.67            0.01
# 0.52            0.52            0.00
# 0.00            0.02            0.01
# 0.00            0.02            0.02
# 0.02            0.03            0.01
# 0.10            0.09            0.01
# 0.51            0.45            0.05
# 1.52            1.51            0.01
# 1.35            1.38            0.03
# 1.58            1.46            0.12
# 1.37            1.36            0.01
# 1.31            1.42            0.11
# 1.02            1.11            0.08
# ======================================================================
# Mean Squared Error: 0.00
# Mean Absolute Error: 0.02
#
# ✓ Weights saved to 'model_weights.pkl'

# %%
# ============================================================================
# GRID SEARCH FOR MAXIMUM OUTPUT
# ============================================================================
print("\n" + "="*70)
print("Searching for maximum output on grid...")
print("="*70)

# Initialize grid for plots
vector_values = np.linspace(0, 1, 22)  # 101 values from 0 to 1

# Generalized version for any number of dimensions
grids = np.meshgrid(*([vector_values] * func_dimensions), indexing='ij')
x_grid = np.column_stack([grid.ravel() for grid in grids])

print(f"Grid size: {x_grid.shape[0]:,} points ({len(vector_values)}^4)")
print("Evaluating model on entire grid...")
# Out:
# ======================================================================
# Searching for maximum output on grid...
# ======================================================================
# Grid size: 113,379,904 points (22^4)
# Evaluating model on entire grid...

# %%
print(x_grid.shape)
# Out:
# (113379904, 6)

# %%
# Make predictions on the entire grid (may take a moment for 101^4 = ~104M points)
# Process in batches to avoid memory issues
batch_size = 100000
n_batches = int(np.ceil(len(x_grid) / batch_size))
all_predictions = []

for i in range(n_batches):
    start_idx = i * batch_size
    end_idx = min((i + 1) * batch_size, len(x_grid))
    batch_predictions = predict(x_grid[start_idx:end_idx], y_mean, y_std)
    all_predictions.append(batch_predictions)

    if (i + 1) % 10 == 0 or (i + 1) == n_batches:
        print(f"  Progress: {i+1}/{n_batches} batches processed")
# Out:
#   Progress: 10/1134 batches processed
#   Progress: 20/1134 batches processed
#   Progress: 30/1134 batches processed
#   Progress: 40/1134 batches processed
#   Progress: 50/1134 batches processed
#   Progress: 60/1134 batches processed
#   Progress: 70/1134 batches processed
#   Progress: 80/1134 batches processed
#   Progress: 90/1134 batches processed
#   Progress: 100/1134 batches processed
#   Progress: 110/1134 batches processed
#   Progress: 120/1134 batches processed
#   Progress: 130/1134 batches processed
#   Progress: 140/1134 batches processed
#   Progress: 150/1134 batches processed
#   Progress: 160/1134 batches processed
#   Progress: 170/1134 batches processed
#   Progress: 180/1134 batches processed
#   Progress: 190/1134 batches processed
#   Progress: 200/1134 batches processed
#   Progress: 210/1134 batches processed
#   Progress: 220/1134 batches processed
#   Progress: 230/1134 batches processed
#   Progress: 240/1134 batches processed
#   Progress: 250/1134 batches processed
#   Progress: 260/1134 batches processed
#   Progress: 270/1134 batches processed
#   Progress: 280/1134 batches processed
#   Progress: 290/1134 batches processed
#   Progress: 300/1134 batches processed
#   Progress: 310/1134 batches processed
#   Progress: 320/1134 batches processed
#   Progress: 330/1134 batches processed
#   Progress: 340/1134 batches processed
#   Progress: 350/1134 batches processed
#   Progress: 360/1134 batches processed
#   Progress: 370/1134 batches processed
#   Progress: 380/1134 batches processed
#   Progress: 390/1134 batches processed
#   Progress: 400/1134 batches processed
#   Progress: 410/1134 batches processed
#   Progress: 420/1134 batches processed
#   Progress: 430/1134 batches processed
#   Progress: 440/1134 batches processed
#   Progress: 450/1134 batches processed
#   Progress: 460/1134 batches processed
#   Progress: 470/1134 batches processed
#   Progress: 480/1134 batches processed
#   Progress: 490/1134 batches processed
#   Progress: 500/1134 batches processed
#   Progress: 510/1134 batches processed
#   Progress: 520/1134 batches processed
#   Progress: 530/1134 batches processed
#   Progress: 540/1134 batches processed
#   Progress: 550/1134 batches processed
#   Progress: 560/1134 batches processed
#   Progress: 570/1134 batches processed
#   Progress: 580/1134 batches processed
#   Progress: 590/1134 batches processed
#   Progress: 600/1134 batches processed
#   Progress: 610/1134 batches processed
#   Progress: 620/1134 batches processed
#   Progress: 630/1134 batches processed
#   Progress: 640/1134 batches processed
#   Progress: 650/1134 batches processed
#   Progress: 660/1134 batches processed
#   Progress: 670/1134 batches processed
#   Progress: 680/1134 batches processed
#   Progress: 690/1134 batches processed
#   Progress: 700/1134 batches processed
#   Progress: 710/1134 batches processed
#   Progress: 720/1134 batches processed
#   Progress: 730/1134 batches processed
#   Progress: 740/1134 batches processed
#   Progress: 750/1134 batches processed
#   Progress: 760/1134 batches processed
#   Progress: 770/1134 batches processed
#   Progress: 780/1134 batches processed
#   Progress: 790/1134 batches processed
#   Progress: 800/1134 batches processed
#   Progress: 810/1134 batches processed
#   Progress: 820/1134 batches processed
#   Progress: 830/1134 batches processed
#   Progress: 840/1134 batches processed
#   Progress: 850/1134 batches processed
#   Progress: 860/1134 batches processed
#   Progress: 870/1134 batches processed
#   Progress: 880/1134 batches processed
#   Progress: 890/1134 batches processed
#   Progress: 900/1134 batches processed
#   Progress: 910/1134 batches processed
#   Progress: 920/1134 batches processed
#   Progress: 930/1134 batches processed
#   Progress: 940/1134 batches processed
#   Progress: 950/1134 batches processed
#   Progress: 960/1134 batches processed
#   Progress: 970/1134 batches processed
#   Progress: 980/1134 batches processed
#   Progress: 990/1134 batches processed
#   Progress: 1000/1134 batches processed
#   Progress: 1010/1134 batches processed
#   Progress: 1020/1134 batches processed
#   Progress: 1030/1134 batches processed
#   Progress: 1040/1134 batches processed
#   Progress: 1050/1134 batches processed
#   Progress: 1060/1134 batches processed
#   Progress: 1070/1134 batches processed
#   Progress: 1080/1134 batches processed
#   Progress: 1090/1134 batches processed
#   Progress: 1100/1134 batches processed
#   Progress: 1110/1134 batches processed
#   Progress: 1120/1134 batches processed
#   Progress: 1130/1134 batches processed
#   Progress: 1134/1134 batches processed

# %%
# Concatenate all predictions
grid_predictions = np.concatenate(all_predictions, axis=0)

# Find the maximum
max_idx = np.argmax(grid_predictions)
max_input = x_grid[max_idx]
max_output = grid_predictions[max_idx, 0]

print("\n" + "="*70)
print("MAXIMUM OUTPUT FOUND:")
print("="*70)
print(f"Input values:  [{max_input[0]:.6f}, {max_input[1]:.6f}, {max_input[2]:.6f}, {max_input[3]:.6f}, {max_input[4]:.6f}, {max_input[5]:.6f}]")
print(f"Predicted output: {max_output:.2f}")
print("="*70)
# Out:
# ======================================================================
# MAXIMUM OUTPUT FOUND:
# ======================================================================
# Input values:  [0.047619, 0.619048, 1.000000, 0.142857, 0.000000, 0.761905]
# Predicted output: 2.50
# ======================================================================

# %%
# Also show top 5 candidates
print("\nTop 5 inputs with highest predicted outputs:")
print("-"*70)
top_5_indices = np.argsort(grid_predictions[:, 0])[-5:][::-1]
for rank, idx in enumerate(top_5_indices, 1):
    inp = x_grid[idx]
    out = grid_predictions[idx, 0]
    print(f"{rank}. Input: [{inp[0]:.4f}, {inp[1]:.4f}, {inp[2]:.4f}, {inp[3]:.4f}] → Output: {out:.2f}")
