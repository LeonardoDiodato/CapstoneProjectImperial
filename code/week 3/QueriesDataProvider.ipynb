# %% [markdown]
# # Queries Data Provider
# This file is used to parse the results for the additional queries of each week.<br>
# This includes both inputData and outputs results for each week.

# %% [markdown]
# Including used libraries

# %%
import numpy as np
import os

# %% [markdown]
# Custom functions definitions

# %%
def parseInput(input):
    out = []
    line = []
    current = []
    buf = ''
    for x in input:
        if x == ',':
            if len(buf) > 0:
                current.append(float(buf))
                buf = ''
        else:
            if x == ']':
                if len(buf) > 0:
                    current.append(float(buf))
                    buf = ''
                    line.append(current)
                    current = []
                else:
                    out.append(line)
                    line = []
            else:
                if x != '\n' and x != ' ' and  x != '[':
                    buf += x
    return out

# %%
def parseOutput(output):
#    print(output)
    out = []
    line = []
    buf = ''
    for x in output:
        if x == ',':
            if len(buf) > 0:
                line.append(np.float64(buf))
                buf = ''
        else:
            if x == ']':
                if len(buf) > 0:
                    line.append(np.float64(buf))
                    buf = ''
                    out.append(line)
                    line = []
                else:
                    out.append(line)
                    line = []
            else:
                if x != '\n' and x != ' ' and  x != '[':
                    buf += x
    return out

# %% [markdown]
# Data parsing

# %%
inputFile = open('./../../data/queries_data/week2/inputs.txt')
inputData = inputFile.read()
inputFile.close()

inputData = inputData.replace('array(', '')
inputData = inputData.replace(')', '')

inputs = []
for i in range(8):
    row = []
    inputs.append(row)

parsed = parseInput(inputData)
#print('result: ', parsed)
for line in parsed:
    for i,func in enumerate(line):
        inputs[i].append(func)
#print(inputs)

newpath = r'./parsed'
if not os.path.exists(newpath):
    os.makedirs(newpath)

for i,values in enumerate(inputs):
    print('function ',i + 1,' inputs: ', values)
    data = np.array(values)
    np.save(f'./parsed/function{i + 1}inputs.npy', data)
# Out:
# function  1  inputs:  [[0.5, 0.5], [0.0, 1.0]]
# function  2  inputs:  [[0.5, 0.5], [0.36, 0.5]]
# function  3  inputs:  [[0.5, 0.5, 0.5], [0.49, 1.0, 1.0]]
# function  4  inputs:  [[0.5, 0.5, 0.5, 0.5], [0.005543, 0.364356, 0.999366, 0.996013]]
# function  5  inputs:  [[0.5, 0.5, 0.5, 0.5], [0.210195, 0.849014, 0.874271, 0.875537]]
# function  6  inputs:  [[0.5, 0.5, 0.5, 0.5, 0.5], [0.017322, 0.062982, 0.093079, 0.018967, 0.059868]]
# function  7  inputs:  [[0.5, 0.5, 0.5, 0.5, 0.5, 0.5], [0.064108, 0.50467, 0.307547, 0.22933, 0.356495, 0.789273]]
# function  8  inputs:  [[0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5], [0.061949, 0.086118, 0.024059, 0.022119, 0.358532, 0.798558, 0.447126, 0.928641]]

# %%
outputFile = open('./../../data/queries_data/week2/outputs.txt')
outputData = outputFile.read()
outputFile.close()

outputData = outputData.replace('np.float64(', '')
outputData = outputData.replace(')', '')

#print(outputData)

outputs = []
for i in range(8):
    row = []
    outputs.append(row)

parsed = parseOutput(outputData)
#print('result: ', parsed)
for line in parsed:
    for i,func in enumerate(line):
        outputs[i].append(func)
#print(outputs)

newpath = r'./parsed'
if not os.path.exists(newpath):
    os.makedirs(newpath)

for i,values in enumerate(outputs):
    print('function ',i + 1,' outputs: ', values)
    data = np.array(values)
    np.save(f'./parsed/function{i + 1}outputs.npy', data)
# Out:
# [2.6752879910742468e-09, 0.7587081650965815, -0.012845061494181114, -3.985750969810286, 32.0025, -1.0738405486176665, 0.5053149917022333, 8.798300000000001]
# [0.0, -0.03926119880595067, -0.47622948272340854, -35.05101840342992, 1060.3898045443261, -2.048147931140859, 1.5242238626243496, 9.6234724089539]
# function  1  outputs:  [np.float64(2.6752879910742468e-09), np.float64(0.0)]
# function  2  outputs:  [np.float64(0.7587081650965815), np.float64(-0.03926119880595067)]
# function  3  outputs:  [np.float64(-0.012845061494181114), np.float64(-0.47622948272340854)]
# function  4  outputs:  [np.float64(-3.985750969810286), np.float64(-35.05101840342992)]
# function  5  outputs:  [np.float64(32.0025), np.float64(1060.3898045443261)]
# function  6  outputs:  [np.float64(-1.0738405486176665), np.float64(-2.048147931140859)]
# function  7  outputs:  [np.float64(0.5053149917022333), np.float64(1.5242238626243496)]
# function  8  outputs:  [np.float64(8.798300000000001), np.float64(9.6234724089539)]
